# %%
from api_routing import *

# %% [markdown]
# 1. Function/API route
# parse the nbib file and store in the database

# %%
# demo.ris -> corpus.json
parse_corpus('demo.ris')
# preview in another function

# %%
# demo.ris -> print(first n entries) and return them in a list
preview_corpus('demo.ris', 1)
# Out:
# PMID- 20610091
# OWN - NLM
# STAT- MEDLINE
# DCOM- 20100812
# LR  - 20100708
# IS  - 1873-4502 (Electronic)
# IS  - 0886-3350 (Linking)
# VI  - 36
# IP  - 7
# DP  - 2010 Jul
# TI  - Islands of lens epithelial cells on the posterior capsule in pseudophakic eyes.
# PG  - 1135-41
# LID - 10.1016/j.jcrs.2010.01.021 [doi]
# AB  - PURPOSE: To evaluate the natural history of focal collections (islands) of lens
#       epithelial cells (LECs) on the posterior capsule after cataract surgery. SETTING:
#       Department of Ophthalmology, St. Thomas' Hospital, London, United Kingdom.
#       METHODS: Patients in previous studies with various intraocular lenses (IOLs) and
#       at least a 2-year follow-up were identified. Postoperative digital
#       retroillumination images of each eye taken at 1, 3, and 6 months and 1 and 2
#       years were assessed for the presence of LEC islands and their incidence,
#       etiology, time of appearance, change with time, and relationship to IOL material.
#       RESULTS: Islands of LECs were identified in 39 eyes with an AcrySof SA60AT IOL,
#       40 eyes with a Rayner Centerflex C570H IOL, and 27 eyes with a Hoya YA60BB IOL.
#       In all groups, the islands tended to appear within 6 months with a decreasing
#       incidence thereafter. Floating LECs that seeded on the posterior capsule (seeded
#       LECs) or LECs left on the posterior capsule at surgery were seen in a small
#       number of eyes. Most islands were derived from regression of a previous LEC
#       membrane, and a majority continued to regress. Intraocular lens material had no
#       influence on the natural history or morphology of the islands. CONCLUSION:
#       Islands of LECs were common postoperatively. Equatorial LECs appeared to be the
#       major cause of clinical posterior capsule opacification (PCO). Floating LECs in
#       the aqueous that seeded on the posterior capsule or LECs left behind after
#       surgery did not appear to contribute to clinical PCO. FINANCIAL DISCLOSURE: No
#       author has a financial or proprietary interest in any material or method
#       mentioned.
# CI  - Copyright 2010 ASCRS and ESCRS. Published by Elsevier Inc. All rights reserved.
# FAU - Nanavaty, Mayank A
# AU  - Nanavaty MA
# AD  - Department of Ophthalmology, St. Thomas' Hospital, Rayne Institute, Kings
#       College, London, United Kingdom.
# FAU - Spalton, David J
# AU  - Spalton DJ
# FAU - Boyce, James
# AU  - Boyce J
# FAU - Vasavada, Abhay R
# AU  - Vasavada AR
# LA  - eng
# PT  - Journal Article
# PL  - United States
# TA  - J Cataract Refract Surg
# JT  - Journal of cataract and refractive surgery
# JID - 8604171
# RN  - 0 (Acrylic Resins)
# SB  - IM
# MH  - Acrylic Resins
# MH  - Cataract/*pathology
# MH  - Epithelial Cells/*pathology
# MH  - Humans
# MH  - Lens Capsule, Crystalline/*pathology
# MH  - *Lens Implantation, Intraocular
# MH  - Lens, Crystalline/pathology
# MH  - *Phacoemulsification
# MH  - *Postoperative Complications
# MH  - Pseudophakia/*pathology
# MH  - Time Factors
# MH  - Visual Acuity/physiology
# EDAT- 2010/07/09 06:00
# MHDA- 2010/08/13 06:00
# CRDT- 2010/07/09 06:00
# PHST- 2009/09/20 00:00 [received]
# PHST- 2010/01/04 00:00 [revised]
# PHST- 2010/01/07 00:00 [accepted]
# PHST- 2010/07/09 06:00 [entrez]
# PHST- 2010/07/09 06:00 [pubmed]
# PHST- 2010/08/13 06:00 [medline]
# AID - S0886-3350(10)00554-7 [pii]
# AID - 10.1016/j.jcrs.2010.01.021 [doi]
# PST - ppublish
# SO  - J Cataract Refract Surg. 2010 Jul;36(7):1135-41. doi: 10.1016/j.jcrs.2010.01.021.
# ["PMID- 24065808\nOWN - NLM\nSTAT- MEDLINE\nDCOM- 20131212\nLR  - 20131028\nIS  - 1552-5783 (Electronic)\nIS  - 0146-0404 (Linking)\nVI  - 54\nIP  - 10\nDP  - 2013 Oct 25\nTI  - High resolution OCT quantitative analysis of the space between the IOL and the \n      posterior capsule during the early cataract postoperative period.\nPG  - 6991-7\nLID - 10.1167/iovs.13-12849 [doi]\nAB  - PURPOSE: We quantitatively characterized the space between the IOL and the \n      posterior capsule (IOL-PC space) during the early postphacoemulsification period, \n      using high resolution optical coherence tomography (OCT). METHODS: We recruited \n      30 eyes of 30 patients who underwent phacoemulsification and randomly divided \n      them into two groups. Acrysof Natural IQ IOLs were implanted in one group (n = \n      15), and Adapt-AO IOLs were implanted into the other (n = 15). A custom-built OCT \n      instrument was used to image the IOL-PC space at 1 day, 1 week, and 1 month after \n      surgery. Slit-lamp examination and auto refraction were performed at each visit. \n      RESULTS: The IOL-PC spaces in the IQ group were 0.72 ± 0.35, 0.40 ± 0.24, and \n      0.23 ± 0.16 mm(2) at 1 day, 1 week, and 1 month after surgery, respectively. At \n      each of these times, the values for the AO group were significantly smaller (P < \n      0.001). Compared to 1 day after surgery, significant changes in the ACDs and \n      refractive errors occurred up to 1 month postoperatively in the IQ group; \n      however, changes in the ACD and refractive error were significant only at 1 week \n      in the AO group. CONCLUSIONS: The decreases in IOL-PC space and in ACD during the \n      early postoperative period were associated with a myopic shift. It appeared that \n      the different IOL designs had a role in closure of the IOL-PC space. High \n      resolution OCT was suitable for quantitative analysis of IOL-PC space. \n      (ClinicalTrials.gov number, NCT01605812.).\nFAU - Tao, Aizhu\nAU  - Tao A\nAD  - School of Ophthalmology and Optometry, Wenzhou Medical University, Wenzhou, \n      Zhejiang, China.\nFAU - Lu, Ping\nAU  - Lu P\nFAU - Li, Jin\nAU  - Li J\nFAU - Shao, Yilei\nAU  - Shao Y\nFAU - Wang, Jianhua\nAU  - Wang J\nFAU - Shen, Meixiao\nAU  - Shen M\nFAU - Zhao, Yinying\nAU  - Zhao Y\nFAU - Lu, Fan\nAU  - Lu F\nLA  - eng\nSI  - ClinicalTrials.gov/NCT01605812\nPT  - Comparative Study\nPT  - Journal Article\nPT  - Randomized Controlled Trial\nPT  - Research Support, Non-U.S. Gov't\nDEP - 20131025\nPL  - United States\nTA  - Invest Ophthalmol Vis Sci\nJT  - Investigative ophthalmology & visual science\nJID - 7703701\nSB  - IM\nMH  - Cataract/*pathology/physiopathology\nMH  - Female\nMH  - Follow-Up Studies\nMH  - Humans\nMH  - *Image Enhancement\nMH  - Lens Capsule, Crystalline/*pathology/surgery\nMH  - *Lenses, Intraocular\nMH  - Male\nMH  - Middle Aged\nMH  - Phacoemulsification/*methods\nMH  - Postoperative Period\nMH  - Time Factors\nMH  - Tomography, Optical Coherence/*methods\nMH  - Visual Acuity\nOTO - NOTNLM\nOT  - intraocular lens\nOT  - optical coherence tomography\nOT  - posterior capsule\nEDAT- 2013/09/26 06:00\nMHDA- 2013/12/18 06:00\nCRDT- 2013/09/26 06:00\nPHST- 2013/09/26 06:00 [entrez]\nPHST- 2013/09/26 06:00 [pubmed]\nPHST- 2013/12/18 06:00 [medline]\nAID - iovs.13-12849 [pii]\nAID - 10.1167/iovs.13-12849 [doi]\nPST - epublish\nSO  - Invest Ophthalmol Vis Sci. 2013 Oct 25;54(10):6991-7. doi: 10.1167/iovs.13-12849.\n\n",
#  "PMID- 20610091\nOWN - NLM\nSTAT- MEDLINE\nDCOM- 20100812\nLR  - 20100708\nIS  - 1873-4502 (Electronic)\nIS  - 0886-3350 (Linking)\nVI  - 36\nIP  - 7\nDP  - 2010 Jul\nTI  - Islands of lens epithelial cells on the posterior capsule in pseudophakic eyes.\nPG  - 1135-41\nLID - 10.1016/j.jcrs.2010.01.021 [doi]\nAB  - PURPOSE: To evaluate the natural history of focal collections (islands) of lens \n      epithelial cells (LECs) on the posterior capsule after cataract surgery. SETTING: \n      Department of Ophthalmology, St. Thomas' Hospital, London, United Kingdom. \n      METHODS: Patients in previous studies with various intraocular lenses (IOLs) and \n      at least a 2-year follow-up were identified. Postoperative digital \n      retroillumination images of each eye taken at 1, 3, and 6 months and 1 and 2 \n      years were assessed for the presence of LEC islands and their incidence, \n      etiology, time of appearance, change with time, and relationship to IOL material. \n      RESULTS: Islands of LECs were identified in 39 eyes with an AcrySof SA60AT IOL, \n      40 eyes with a Rayner Centerflex C570H IOL, and 27 eyes with a Hoya YA60BB IOL. \n      In all groups, the islands tended to appear within 6 months with a decreasing \n      incidence thereafter. Floating LECs that seeded on the posterior capsule (seeded \n      LECs) or LECs left on the posterior capsule at surgery were seen in a small \n      number of eyes. Most islands were derived from regression of a previous LEC \n      membrane, and a majority continued to regress. Intraocular lens material had no \n      influence on the natural history or morphology of the islands. CONCLUSION: \n      Islands of LECs were common postoperatively. Equatorial LECs appeared to be the \n      major cause of clinical posterior capsule opacification (PCO). Floating LECs in \n      the aqueous that seeded on the posterior capsule or LECs left behind after \n      surgery did not appear to contribute to clinical PCO. FINANCIAL DISCLOSURE: No \n      author has a financial or proprietary interest in any material or method \n      mentioned.\nCI  - Copyright 2010 ASCRS and ESCRS. Published by Elsevier Inc. All rights reserved.\nFAU - Nanavaty, Mayank A\nAU  - Nanavaty MA\nAD  - Department of Ophthalmology, St. Thomas' Hospital, Rayne Institute, Kings \n      College, London, United Kingdom.\nFAU - Spalton, David J\nAU  - Spalton DJ\nFAU - Boyce, James\nAU  - Boyce J\nFAU - Vasavada, Abhay R\nAU  - Vasavada AR\nLA  - eng\nPT  - Journal Article\nPL  - United States\nTA  - J Cataract Refract Surg\nJT  - Journal of cataract and refractive surgery\nJID - 8604171\nRN  - 0 (Acrylic Resins)\nSB  - IM\nMH  - Acrylic Resins\nMH  - Cataract/*pathology\nMH  - Epithelial Cells/*pathology\nMH  - Humans\nMH  - Lens Capsule, Crystalline/*pathology\nMH  - *Lens Implantation, Intraocular\nMH  - Lens, Crystalline/pathology\nMH  - *Phacoemulsification\nMH  - *Postoperative Complications\nMH  - Pseudophakia/*pathology\nMH  - Time Factors\nMH  - Visual Acuity/physiology\nEDAT- 2010/07/09 06:00\nMHDA- 2010/08/13 06:00\nCRDT- 2010/07/09 06:00\nPHST- 2009/09/20 00:00 [received]\nPHST- 2010/01/04 00:00 [revised]\nPHST- 2010/01/07 00:00 [accepted]\nPHST- 2010/07/09 06:00 [entrez]\nPHST- 2010/07/09 06:00 [pubmed]\nPHST- 2010/08/13 06:00 [medline]\nAID - S0886-3350(10)00554-7 [pii]\nAID - 10.1016/j.jcrs.2010.01.021 [doi]\nPST - ppublish\nSO  - J Cataract Refract Surg. 2010 Jul;36(7):1135-41. doi: 10.1016/j.jcrs.2010.01.021.\n\n"]

# %%
# show in notebook only
pico_data = {
         "P": ["Aged 19 and over", "Extraction Of Catatract"],
         "I": ["Insertion Of Intraocular Lens"],
         "C": ["Insertion Of Intraocular Lens"],
         "O":["Finding Of Color Vision", "Visual Acuity Testing"] 
    }

# %%
# show in notebook only
parse_query(pico_data)
# Out:
# 'Aged 19 and over Extraction Of Catatract Insertion Of Intraocular Lens Finding Of Color Vision Visual Acuity Testing'

# %%
# pico.json -> query.json
parse_query('pico.json', output_path = 'query.json')

# %%
# onvert_jsonl('corpus.jsonl', 'corpus_tevatron.jsonl')

# %%
# corpus.json -> docid2pmid.json, corpus4tevatron.jsonl, pmids.json and return in three dicts
docid2pmid, corpus4tevatron, pmids = corpus_converter('corpus.json')

# %%
docid2pmid[24065808]
# Out:
# '24065808'

# %%
corpus4tevatron[0]
# Out:
# {'docid': 24065808,
#  'title': 'High resolution OCT quantitative analysis of the space between the IOL and the posterior capsule during the early cataract postoperative period.',
#  'text': 'PURPOSE: We quantitatively characterized the space between the IOL and the posterior capsule (IOL-PC space) during the early postphacoemulsification period, using high resolution optical coherence tomography (OCT). METHODS: We recruited 30 eyes of 30 patients who underwent phacoemulsification and randomly divided them into two groups. Acrysof Natural IQ IOLs were implanted in one group (n = 15), and Adapt-AO IOLs were implanted into the other (n = 15). A custom-built OCT instrument was used to image the IOL-PC space at 1 day, 1 week, and 1 month after surgery. Slit-lamp examination and auto refraction were performed at each visit. RESULTS: The IOL-PC spaces in the IQ group were 0.72 ± 0.35, 0.40 ± 0.24, and 0.23 ± 0.16 mm(2) at 1 day, 1 week, and 1 month after surgery, respectively. At each of these times, the values for the AO group were significantly smaller (P < 0.001). Compared to 1 day after surgery, significant changes in the ACDs and refractive errors occurred up to 1 month postoperatively in the IQ group; however, changes in the ACD and refractive error were significant only at 1 week in the AO group. CONCLUSIONS: The decreases in IOL-PC space and in ACD during the early postoperative period were associated with a myopic shift. It appeared that the different IOL designs had a role in closure of the IOL-PC space. High resolution OCT was suitable for quantitative analysis of IOL-PC space. (ClinicalTrials.gov number, NCT01605812.).'}

# %%
pmids["24065808"]
# Out:
# {'title': 'High resolution OCT quantitative analysis of the space between the IOL and the posterior capsule during the early cataract postoperative period.',
#  'abstract': 'PURPOSE: We quantitatively characterized the space between the IOL and the posterior capsule (IOL-PC space) during the early postphacoemulsification period, using high resolution optical coherence tomography (OCT). METHODS: We recruited 30 eyes of 30 patients who underwent phacoemulsification and randomly divided them into two groups. Acrysof Natural IQ IOLs were implanted in one group (n = 15), and Adapt-AO IOLs were implanted into the other (n = 15). A custom-built OCT instrument was used to image the IOL-PC space at 1 day, 1 week, and 1 month after surgery. Slit-lamp examination and auto refraction were performed at each visit. RESULTS: The IOL-PC spaces in the IQ group were 0.72 ± 0.35, 0.40 ± 0.24, and 0.23 ± 0.16 mm(2) at 1 day, 1 week, and 1 month after surgery, respectively. At each of these times, the values for the AO group were significantly smaller (P < 0.001). Compared to 1 day after surgery, significant changes in the ACDs and refractive errors occurred up to 1 month postoperatively in the IQ group; however, changes in the ACD and refractive error were significant only at 1 week in the AO group. CONCLUSIONS: The decreases in IOL-PC space and in ACD during the early postoperative period were associated with a myopic shift. It appeared that the different IOL designs had a role in closure of the IOL-PC space. High resolution OCT was suitable for quantitative analysis of IOL-PC space. (ClinicalTrials.gov number, NCT01605812.).',
#  'authors': [{'author': 'Tao, Aizhu',
#    'author_abbreviated': 'Tao A',
#    'affiliations': ['School of Ophthalmology and Optometry, Wenzhou Medical University, Wenzhou, Zhejiang, China.'],
#    'first_name': 'Aizhu',
#    'last_name': 'Tao'},
#   {'author': 'Lu, Ping',
#    'author_abbreviated': 'Lu P',
#    'first_name': 'Ping',
#    'last_name': 'Lu'},
#   {'author': 'Li, Jin',
#    'author_abbreviated': 'Li J',
#    'first_name': 'Jin',
#    'last_name': 'Li'},
#   {'author': 'Shao, Yilei',
#    'author_abbreviated': 'Shao Y',
#    'first_name': 'Yilei',
#    'last_name': 'Shao'},
#   {'author': 'Wang, Jianhua',
#    'author_abbreviated': 'Wang J',
#    'first_name': 'Jianhua',
#    'last_name': 'Wang'},
#   {'author': 'Shen, Meixiao',
#    'author_abbreviated': 'Shen M',
#    'first_name': 'Meixiao',
#    'last_name': 'Shen'},
#   {'author': 'Zhao, Yinying',
#    'author_abbreviated': 'Zhao Y',
#    'first_name': 'Yinying',
#    'last_name': 'Zhao'},
#   {'author': 'Lu, Fan',
#    'author_abbreviated': 'Lu F',
#    'first_name': 'Fan',
#    'last_name': 'Lu'}]}

# %% [markdown]
# 2. Function/API route
# get data from UI and save it to ranking_pages and read data from this variable to perform re-ranking based on Rocchio
#
# * tested for initial ranking with tevatron
# * not yet for iterative ranking with dense retriever

# %%
get_init_ranking('clef19_intervention_rank_pico.txt', 'ranking_pages.json', show_docs=25)

# %% [markdown]
# 3. Function/API route
# read ranking_pages, extract 3 lists and save to 3 fields in the database, i.e., include docs, xxclude docs and
# maybe docs. This is to let a user to see in 3 tables according to Include, Exclude and not_sure.
#
# * issues here are on certain inconsistent data formats:
#   * between sys design and dense-feedback lib, see `data_flow.drawio`
#   * inside the sys design: e.g. pmid or pubmed_id, and int or str

# %%
with open('fixed_ranking_pages.json', 'r') as infile:
        for line in infile:
            print(line)
# Out:
# [
#
#     {
#
#         "type": "init_ranking",
#
#         "ranking_at": "",
#
#         "in_page_docs": [
#
#             {
#
#                 "rank": 1,
#
#                 "pmid": "23471324",
#
#                 "score": 132.36045837402344,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 2,
#
#                 "pmid": "16631056",
#
#                 "score": 131.1927490234375,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 3,
#
#                 "pmid": "19575919",
#
#                 "score": 130.38162231445312,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 4,
#
#                 "pmid": "16473225",
#
#                 "score": 130.22390747070312,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 5,
#
#                 "pmid": "17056369",
#
#                 "score": 130.19273376464844,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 6,
#
#                 "pmid": "16338566",
#
#                 "score": 129.77841186523438,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 7,
#
#                 "pmid": "18191090",
#
#                 "score": 129.64715576171875,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 8,
#
#                 "pmid": "17444040",
#
#                 "score": 129.6131591796875,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 9,
#
#                 "pmid": "22108107",
#
#                 "score": 129.3938446044922,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 10,
#
#                 "pmid": "23461152",
#
#                 "score": 129.33865356445312,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 11,
#
#                 "pmid": "26096521",
#
#                 "score": 129.23013305664062,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 12,
#
#                 "pmid": "17867510",
#
#                 "score": 129.2013702392578,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 13,
#
#                 "pmid": "19101429",
#
#                 "score": 129.00082397460938,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 14,
#
#                 "pmid": "27966269",
#
#                 "score": 128.94635009765625,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 15,
#
#                 "pmid": "16597662",
#
#                 "score": 128.94204711914062,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 16,
#
#                 "pmid": "16863969",
#
#                 "score": 128.84152221679688,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 17,
#
#                 "pmid": "21350691",
#
#                 "score": 128.8072052001953,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 18,
#
#                 "pmid": "16445445",
#
#                 "score": 128.78982543945312,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 19,
#
#                 "pmid": "19118695",
#
#                 "score": 128.72802734375,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 20,
#
#                 "pmid": "18471631",
#
#                 "score": 128.63986206054688,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 21,
#
#                 "pmid": "17397731",
#
#                 "score": 128.57127380371094,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 22,
#
#                 "pmid": "24756476",
#
#                 "score": 128.52505493164062,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 23,
#
#                 "pmid": "19304088",
#
#                 "score": 128.40782165527344,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 24,
#
#                 "pmid": "19333692",
#
#                 "score": 128.3487091064453,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             },
#
#             {
#
#                 "rank": 25,
#
#                 "pmid": "18361983",
#
#                 "score": 128.29364013671875,
#
#                 "feedback": "feedback_value",
#
#                 "feedback_created_at": "yyyy-mm-ddThhmm.ss+00.00",
#
#                 "feedback_updated_at": "yyyy-mm-ddThhmm.ss+00.00"
#
#             }
#
#         ],
#
#         "remaining_ranking": [
#
#             {
#
#                 "rank": 26,
#
#                 "pmid": "21111309",
#
#                 "score": 128.10885620117188
#
#             },
#
#             {
#
#                 "rank": 27,
#
#                 "pmid": "17964398",
#
#                 "score": 128.0149688720703
#
#             },
#
#             {
#
#                 "rank": 28,
#
#                 "pmid": "22287168",
#
#                 "score": 127.90097045898438
#
#             },
#
#             {
#
#                 "rank": 29,
#
#                 "pmid": "22520306",
#
#                 "score": 127.87181091308594
#
#             },
#
#             {
#
#                 "rank": 30,
#
#                 "pmid": "20665986",
#
#                 "score": 127.86184692382812
#
#             },
#
#             {
#
#                 "rank": 31,
#
#                 "pmid": "15234295",
#
#                 "score": 127.78459930419922
#
#             },
#
#             {
#
#                 "rank": 32,
#
#                 "pmid": "19643497",
#
#                 "score": 127.768310546875
#
#             },
#
#             {
#
#                 "rank": 33,
#
#                 "pmid": "26286756",
#
#                 "score": 127.76782989501953
#
#             },
#
#             {
#
#                 "rank": 34,
#
#                 "pmid": "25838942",
#
#                 "score": 127.67823028564453
#
#             },
#
#             {
#
#                 "rank": 35,
#
#                 "pmid": "25216318",
#
#                 "score": 127.46647644042969
#
#             },
#
#             {
#
#                 "rank": 36,
#
#                 "pmid": "19662914",
#
#                 "score": 127.40303039550781
#
#             },
#
#             {
#
#                 "rank": 37,
#
#                 "pmid": "19820794",
#
#                 "score": 127.37431335449219
#
#             },
#
#             {
#
#                 "rank": 38,
#
#                 "pmid": "18464801",
#
#                 "score": 127.23814392089844
#
#             },
#
#             {
#
#                 "rank": 39,
#
#                 "pmid": "19410947",
#
#                 "score": 127.18842315673828
#
#             },
#
#             {
#
#                 "rank": 40,
#
#                 "pmid": "15852166",
#
#                 "score": 127.03942108154297
#
#             },
#
#             {
#
#                 "rank": 41,
#
#                 "pmid": "18721708",
#
#                 "score": 126.98091125488281
#
#             },
#
#             {
#
#                 "rank": 42,
#
#                 "pmid": "19576065",
#
#                 "score": 126.93975830078125
#
#             },
#
#             {
#
#                 "rank": 43,
#
#                 "pmid": "21752591",
#
#                 "score": 126.87960815429688
#
#             },
#
#             {
#
#                 "rank": 44,
#
#                 "pmid": "17912933",
#
#                 "score": 126.84327697753906
#
#             },
#
#             {
#
#                 "rank": 45,
#
#                 "pmid": "22727284",
#
#                 "score": 126.78041076660156
#
#             },
#
#             {
#
#                 "rank": 46,
#
#                 "pmid": "22952402",
#
#                 "score": 126.73774719238281
#
#             },
#
#             {
#
#                 "rank": 47,
#
#                 "pmid": "22321501",
#
#                 "score": 126.6017074584961
#
#             },
#
#             {
#
#                 "rank": 48,
#
#                 "pmid": "18404118",
#
#                 "score": 126.513916015625
#
#             },
#
#             {
#
#                 "rank": 49,
#
#                 "pmid": "15682919",
#
#                 "score": 126.45832824707031
#
#             },
#
#             {
#
#                 "rank": 50,
#
#                 "pmid": "22067557",
#
#                 "score": 126.44808959960938
#
#             },
#
#             {
#
#                 "rank": 51,
#
#                 "pmid": "16564998",
#
#                 "score": 126.41815948486328
#
#             },
#
#             {
#
#                 "rank": 52,
#
#                 "pmid": "17362457",
#
#                 "score": 126.36015319824219
#
#             },
#
#             {
#
#                 "rank": 53,
#
#                 "pmid": "24021181",
#
#                 "score": 126.34976196289062
#
#             },
#
#             {
#
#                 "rank": 54,
#
#                 "pmid": "23608567",
#
#                 "score": 126.32183074951172
#
#             },
#
#             {
#
#                 "rank": 55,
#
#                 "pmid": "17260315",
#
#                 "score": 126.27311706542969
#
#             },
#
#             {
#
#                 "rank": 56,
#
#                 "pmid": "21183103",
#
#                 "score": 126.25241088867188
#
#             },
#
#             {
#
#                 "rank": 57,
#
#                 "pmid": "15606466",
#
#                 "score": 126.20354461669922
#
#             },
#
#             {
#
#                 "rank": 58,
#
#                 "pmid": "26233628",
#
#                 "score": 126.18363952636719
#
#             },
#
#             {
#
#                 "rank": 59,
#
#                 "pmid": "16445446",
#
#                 "score": 126.14916229248047
#
#             },
#
#             {
#
#                 "rank": 60,
#
#                 "pmid": "26968411",
#
#                 "score": 126.118408203125
#
#             },
#
#             {
#
#                 "rank": 61,
#
#                 "pmid": "19491981",
#
#                 "score": 126.11793518066406
#
#             },
#
#             {
#
#                 "rank": 62,
#
#                 "pmid": "17469752",
#
#                 "score": 125.99193572998047
#
#             },
#
#             {
#
#                 "rank": 63,
#
#                 "pmid": "28676040",
#
#                 "score": 125.94467163085938
#
#             },
#
#             {
#
#                 "rank": 64,
#
#                 "pmid": "28002333",
#
#                 "score": 125.93553161621094
#
#             },
#
#             {
#
#                 "rank": 65,
#
#                 "pmid": "21950699",
#
#                 "score": 125.92443084716797
#
#             },
#
#             {
#
#                 "rank": 66,
#
#                 "pmid": "26471051",
#
#                 "score": 125.87043762207031
#
#             },
#
#             {
#
#                 "rank": 67,
#
#                 "pmid": "17397740",
#
#                 "score": 125.8631591796875
#
#             },
#
#             {
#
#                 "rank": 68,
#
#                 "pmid": "27935597",
#
#                 "score": 125.65028381347656
#
#             },
#
#             {
#
#                 "rank": 69,
#
#                 "pmid": "3991126",
#
#                 "score": 125.5823974609375
#
#             },
#
#             {
#
#                 "rank": 70,
#
#                 "pmid": "23467788",
#
#                 "score": 125.57616424560547
#
#             },
#
#             {
#
#                 "rank": 71,
#
#                 "pmid": "19545814",
#
#                 "score": 125.49969482421875
#
#             },
#
#             {
#
#                 "rank": 72,
#
#                 "pmid": "21641040",
#
#                 "score": 125.4690933227539
#
#             },
#
#             {
#
#                 "rank": 73,
#
#                 "pmid": "17445897",
#
#                 "score": 125.18612670898438
#
#             },
#
#             {
#
#                 "rank": 74,
#
#                 "pmid": "22205829",
#
#                 "score": 125.03965759277344
#
#             },
#
#             {
#
#                 "rank": 75,
#
#                 "pmid": "22139617",
#
#                 "score": 125.0116195678711
#
#             },
#
#             {
#
#                 "rank": 76,
#
#                 "pmid": "22858061",
#
#                 "score": 124.90310668945312
#
#             },
#
#             {
#
#                 "rank": 77,
#
#                 "pmid": "19304086",
#
#                 "score": 124.779296875
#
#             },
#
#             {
#
#                 "rank": 78,
#
#                 "pmid": "2589059",
#
#                 "score": 124.51930236816406
#
#             },
#
#             {
#
#                 "rank": 79,
#
#                 "pmid": "18976313",
#
#                 "score": 124.3486099243164
#
#             },
#
#             {
#
#                 "rank": 80,
#
#                 "pmid": "17420703",
#
#                 "score": 124.33673858642578
#
#             },
#
#             {
#
#                 "rank": 81,
#
#                 "pmid": "24269140",
#
#                 "score": 124.15489959716797
#
#             },
#
#             {
#
#                 "rank": 82,
#
#                 "pmid": "22527312",
#
#                 "score": 123.91968536376953
#
#             },
#
#             {
#
#                 "rank": 83,
#
#                 "pmid": "20610091",
#
#                 "score": 123.73002624511719
#
#             },
#
#             {
#
#                 "rank": 84,
#
#                 "pmid": "19781467",
#
#                 "score": 123.7062759399414
#
#             },
#
#             {
#
#                 "rank": 85,
#
#                 "pmid": "21111310",
#
#                 "score": 123.64726257324219
#
#             },
#
#             {
#
#                 "rank": 86,
#
#                 "pmid": "16473224",
#
#                 "score": 123.38107299804688
#
#             },
#
#             {
#
#                 "rank": 87,
#
#                 "pmid": "3883964",
#
#                 "score": 123.19551086425781
#
#             },
#
#             {
#
#                 "rank": 88,
#
#                 "pmid": "15093654",
#
#                 "score": 123.10221862792969
#
#             },
#
#             {
#
#                 "rank": 89,
#
#                 "pmid": "24771157",
#
#                 "score": 122.99810791015625
#
#             },
#
#             {
#
#                 "rank": 90,
#
#                 "pmid": "21856011",
#
#                 "score": 122.98273468017578
#
#             },
#
#             {
#
#                 "rank": 91,
#
#                 "pmid": "19251148",
#
#                 "score": 122.9373779296875
#
#             },
#
#             {
#
#                 "rank": 92,
#
#                 "pmid": "24065808",
#
#                 "score": 122.90177154541016
#
#             },
#
#             {
#
#                 "rank": 93,
#
#                 "pmid": "24205001",
#
#                 "score": 122.86001586914062
#
#             },
#
#             {
#
#                 "rank": 94,
#
#                 "pmid": "20202534",
#
#                 "score": 122.64827728271484
#
#             },
#
#             {
#
#                 "rank": 95,
#
#                 "pmid": "19629514",
#
#                 "score": 122.64456176757812
#
#             },
#
#             {
#
#                 "rank": 96,
#
#                 "pmid": "21111307",
#
#                 "score": 122.63832092285156
#
#             },
#
#             {
#
#                 "rank": 97,
#
#                 "pmid": "24970263",
#
#                 "score": 122.56896209716797
#
#             },
#
#             {
#
#                 "rank": 98,
#
#                 "pmid": "17534810",
#
#                 "score": 122.44052124023438
#
#             },
#
#             {
#
#                 "rank": 99,
#
#                 "pmid": "21883771",
#
#                 "score": 122.28335571289062
#
#             },
#
#             {
#
#                 "rank": 100,
#
#                 "pmid": "17416326",
#
#                 "score": 122.07499694824219
#
#             },
#
#             {
#
#                 "rank": 101,
#
#                 "pmid": "24158845",
#
#                 "score": 121.90252685546875
#
#             },
#
#             {
#
#                 "rank": 102,
#
#                 "pmid": "18856236",
#
#                 "score": 121.73493957519531
#
#             },
#
#             {
#
#                 "rank": 103,
#
#                 "pmid": "1794814",
#
#                 "score": 121.70700073242188
#
#             },
#
#             {
#
#                 "rank": 104,
#
#                 "pmid": "15662502",
#
#                 "score": 121.67713928222656
#
#             },
#
#             {
#
#                 "rank": 105,
#
#                 "pmid": "14687197",
#
#                 "score": 121.24484252929688
#
#             },
#
#             {
#
#                 "rank": 106,
#
#                 "pmid": "25103657",
#
#                 "score": 121.15800476074219
#
#             },
#
#             {
#
#                 "rank": 107,
#
#                 "pmid": "1087839",
#
#                 "score": 121.07058715820312
#
#             },
#
#             {
#
#                 "rank": 108,
#
#                 "pmid": "18850550",
#
#                 "score": 121.00727081298828
#
#             },
#
#             {
#
#                 "rank": 109,
#
#                 "pmid": "23074519",
#
#                 "score": 120.89624786376953
#
#             },
#
#             {
#
#                 "rank": 110,
#
#                 "pmid": "22744386",
#
#                 "score": 120.66741943359375
#
#             },
#
#             {
#
#                 "rank": 111,
#
#                 "pmid": "23211814",
#
#                 "score": 120.63285827636719
#
#             },
#
#             {
#
#                 "rank": 112,
#
#                 "pmid": "19140849",
#
#                 "score": 120.52877807617188
#
#             },
#
#             {
#
#                 "rank": 113,
#
#                 "pmid": "17159440",
#
#                 "score": 120.42298889160156
#
#             },
#
#             {
#
#                 "rank": 114,
#
#                 "pmid": "23472744",
#
#                 "score": 120.39947509765625
#
#             },
#
#             {
#
#                 "rank": 115,
#
#                 "pmid": "28264100",
#
#                 "score": 120.37767028808594
#
#             },
#
#             {
#
#                 "rank": 116,
#
#                 "pmid": "3466465",
#
#                 "score": 120.18171691894531
#
#             },
#
#             {
#
#                 "rank": 117,
#
#                 "pmid": "25612055",
#
#                 "score": 120.153564453125
#
#             },
#
#             {
#
#                 "rank": 118,
#
#                 "pmid": "27432203",
#
#                 "score": 120.13245391845703
#
#             },
#
#             {
#
#                 "rank": 119,
#
#                 "pmid": "8060925",
#
#                 "score": 119.87801361083984
#
#             },
#
#             {
#
#                 "rank": 120,
#
#                 "pmid": "18988171",
#
#                 "score": 119.7906494140625
#
#             },
#
#             {
#
#                 "rank": 121,
#
#                 "pmid": "22412976",
#
#                 "score": 119.69992065429688
#
#             },
#
#             {
#
#                 "rank": 122,
#
#                 "pmid": "16755682",
#
#                 "score": 119.65153503417969
#
#             },
#
#             {
#
#                 "rank": 123,
#
#                 "pmid": "12614752",
#
#                 "score": 119.63412475585938
#
#             },
#
#             {
#
#                 "rank": 124,
#
#                 "pmid": "18581789",
#
#                 "score": 119.44100952148438
#
#             },
#
#             {
#
#                 "rank": 125,
#
#                 "pmid": "20030543",
#
#                 "score": 119.36769104003906
#
#             },
#
#             {
#
#                 "rank": 126,
#
#                 "pmid": "27380430",
#
#                 "score": 119.20855712890625
#
#             },
#
#             {
#
#                 "rank": 127,
#
#                 "pmid": "7514581",
#
#                 "score": 118.94424438476562
#
#             },
#
#             {
#
#                 "rank": 128,
#
#                 "pmid": "4437543",
#
#                 "score": 118.92313385009766
#
#             },
#
#             {
#
#                 "rank": 129,
#
#                 "pmid": "8871173",
#
#                 "score": 118.88539123535156
#
#             },
#
#             {
#
#                 "rank": 130,
#
#                 "pmid": "17084803",
#
#                 "score": 118.86241149902344
#
#             },
#
#             {
#
#                 "rank": 131,
#
#                 "pmid": "18361993",
#
#                 "score": 118.52161407470703
#
#             },
#
#             {
#
#                 "rank": 132,
#
#                 "pmid": "21951571",
#
#                 "score": 118.48689270019531
#
#             },
#
#             {
#
#                 "rank": 133,
#
#                 "pmid": "24009749",
#
#                 "score": 118.4853286743164
#
#             },
#
#             {
#
#                 "rank": 134,
#
#                 "pmid": "21455768",
#
#                 "score": 118.39631652832031
#
#             },
#
#             {
#
#                 "rank": 135,
#
#                 "pmid": "27785596",
#
#                 "score": 118.38153839111328
#
#             },
#
#             {
#
#                 "rank": 136,
#
#                 "pmid": "25968007",
#
#                 "score": 118.18231964111328
#
#             },
#
#             {
#
#                 "rank": 137,
#
#                 "pmid": "27256717",
#
#                 "score": 118.07329559326172
#
#             },
#
#             {
#
#                 "rank": 138,
#
#                 "pmid": "16834830",
#
#                 "score": 117.96321868896484
#
#             },
#
#             {
#
#                 "rank": 139,
#
#                 "pmid": "27226262",
#
#                 "score": 117.87645721435547
#
#             },
#
#             {
#
#                 "rank": 140,
#
#                 "pmid": "2748876",
#
#                 "score": 117.83944702148438
#
#             },
#
#             {
#
#                 "rank": 141,
#
#                 "pmid": "2596543",
#
#                 "score": 117.63770294189453
#
#             },
#
#             {
#
#                 "rank": 142,
#
#                 "pmid": "7920190",
#
#                 "score": 117.5777587890625
#
#             },
#
#             {
#
#                 "rank": 143,
#
#                 "pmid": "15870573",
#
#                 "score": 117.43760681152344
#
#             },
#
#             {
#
#                 "rank": 144,
#
#                 "pmid": "22864026",
#
#                 "score": 117.33114624023438
#
#             },
#
#             {
#
#                 "rank": 145,
#
#                 "pmid": "26074032",
#
#                 "score": 116.85218811035156
#
#             },
#
#             {
#
#                 "rank": 146,
#
#                 "pmid": "19628740",
#
#                 "score": 116.84257507324219
#
#             },
#
#             {
#
#                 "rank": 147,
#
#                 "pmid": "27464575",
#
#                 "score": 116.5731430053711
#
#             },
#
#             {
#
#                 "rank": 148,
#
#                 "pmid": "21886359",
#
#                 "score": 116.1737060546875
#
#             },
#
#             {
#
#                 "rank": 149,
#
#                 "pmid": "27420965",
#
#                 "score": 116.00005340576172
#
#             },
#
#             {
#
#                 "rank": 150,
#
#                 "pmid": "26478261",
#
#                 "score": 115.94772338867188
#
#             },
#
#             {
#
#                 "rank": 151,
#
#                 "pmid": "22762040",
#
#                 "score": 114.91752624511719
#
#             },
#
#             {
#
#                 "rank": 152,
#
#                 "pmid": "22732187",
#
#                 "score": 114.67524719238281
#
#             },
#
#             {
#
#                 "rank": 153,
#
#                 "pmid": "19896637",
#
#                 "score": 114.64181518554688
#
#             },
#
#             {
#
#                 "rank": 154,
#
#                 "pmid": "14724954",
#
#                 "score": 114.61380004882812
#
#             },
#
#             {
#
#                 "rank": 155,
#
#                 "pmid": "25582206",
#
#                 "score": 113.87998962402344
#
#             },
#
#             {
#
#                 "rank": 156,
#
#                 "pmid": "27580077",
#
#                 "score": 113.55016326904297
#
#             },
#
#             {
#
#                 "rank": 157,
#
#                 "pmid": "8745513",
#
#                 "score": 113.42311096191406
#
#             },
#
#             {
#
#                 "rank": 158,
#
#                 "pmid": "15988925",
#
#                 "score": 113.42245483398438
#
#             },
#
#             {
#
#                 "rank": 159,
#
#                 "pmid": "15702781",
#
#                 "score": 113.01920318603516
#
#             },
#
#             {
#
#                 "rank": 160,
#
#                 "pmid": "23742627",
#
#                 "score": 112.97728729248047
#
#             },
#
#             {
#
#                 "rank": 161,
#
#                 "pmid": "23882696",
#
#                 "score": 112.95130157470703
#
#             },
#
#             {
#
#                 "rank": 162,
#
#                 "pmid": "12877897",
#
#                 "score": 112.75483703613281
#
#             },
#
#             {
#
#                 "rank": 163,
#
#                 "pmid": "3454916",
#
#                 "score": 112.66812133789062
#
#             },
#
#             {
#
#                 "rank": 164,
#
#                 "pmid": "21094670",
#
#                 "score": 112.54721069335938
#
#             },
#
#             {
#
#                 "rank": 165,
#
#                 "pmid": "3211494",
#
#                 "score": 112.04020690917969
#
#             },
#
#             {
#
#                 "rank": 166,
#
#                 "pmid": "3454917",
#
#                 "score": 111.99664306640625
#
#             },
#
#             {
#
#                 "rank": 167,
#
#                 "pmid": "3772782",
#
#                 "score": 110.78815460205078
#
#             },
#
#             {
#
#                 "rank": 168,
#
#                 "pmid": "18195239",
#
#                 "score": 110.307861328125
#
#             },
#
#             {
#
#                 "rank": 169,
#
#                 "pmid": "18075744",
#
#                 "score": 110.06331634521484
#
#             },
#
#             {
#
#                 "rank": 170,
#
#                 "pmid": "28155996",
#
#                 "score": 109.59431457519531
#
#             },
#
#             {
#
#                 "rank": 171,
#
#                 "pmid": "16445433",
#
#                 "score": 109.05743408203125
#
#             },
#
#             {
#
#                 "rank": 172,
#
#                 "pmid": "26589689",
#
#                 "score": 108.85140991210938
#
#             },
#
#             {
#
#                 "rank": 173,
#
#                 "pmid": "26850586",
#
#                 "score": 108.55923461914062
#
#             },
#
#             {
#
#                 "rank": 174,
#
#                 "pmid": "25223707",
#
#                 "score": 108.16583251953125
#
#             },
#
#             {
#
#                 "rank": 175,
#
#                 "pmid": "16792735",
#
#                 "score": 107.76007080078125
#
#             },
#
#             {
#
#                 "rank": 176,
#
#                 "pmid": "24597610",
#
#                 "score": 107.40320587158203
#
#             },
#
#             {
#
#                 "rank": 177,
#
#                 "pmid": "19700536",
#
#                 "score": 107.11094665527344
#
#             },
#
#             {
#
#                 "rank": 178,
#
#                 "pmid": "22653894",
#
#                 "score": 106.985595703125
#
#             },
#
#             {
#
#                 "rank": 179,
#
#                 "pmid": "22594975",
#
#                 "score": 106.69032287597656
#
#             },
#
#             {
#
#                 "rank": 180,
#
#                 "pmid": "26708928",
#
#                 "score": 106.35520935058594
#
#             },
#
#             {
#
#                 "rank": 181,
#
#                 "pmid": "1788533",
#
#                 "score": 103.6994857788086
#
#             },
#
#             {
#
#                 "rank": 182,
#
#                 "pmid": "15705234",
#
#                 "score": 103.68241882324219
#
#             },
#
#             {
#
#                 "rank": 183,
#
#                 "pmid": "18320254",
#
#                 "score": 103.14327239990234
#
#             },
#
#             {
#
#                 "rank": 184,
#
#                 "pmid": "15302349",
#
#                 "score": 102.7305908203125
#
#             },
#
#             {
#
#                 "rank": 185,
#
#                 "pmid": "26491964",
#
#                 "score": 102.0655288696289
#
#             },
#
#             {
#
#                 "rank": 186,
#
#                 "pmid": "20355006",
#
#                 "score": 100.86202239990234
#
#             },
#
#             {
#
#                 "rank": 187,
#
#                 "pmid": "11553757",
#
#                 "score": 100.58393096923828
#
#             },
#
#             {
#
#                 "rank": 188,
#
#                 "pmid": "23776409",
#
#                 "score": 98.65303039550781
#
#             },
#
#             {
#
#                 "rank": 189,
#
#                 "pmid": "9790588",
#
#                 "score": 96.45445251464844
#
#             },
#
#             {
#
#                 "rank": 190,
#
#                 "pmid": "25680758",
#
#                 "score": 95.01988220214844
#
#             },
#
#             {
#
#                 "rank": 191,
#
#                 "pmid": "14769042",
#
#                 "score": 94.56123352050781
#
#             },
#
#             {
#
#                 "rank": 192,
#
#                 "pmid": "12411437",
#
#                 "score": 94.08488464355469
#
#             },
#
#             {
#
#                 "rank": 193,
#
#                 "pmid": "10809448",
#
#                 "score": 93.08284759521484
#
#             },
#
#             {
#
#                 "rank": 194,
#
#                 "pmid": "11260499",
#
#                 "score": 92.731201171875
#
#             },
#
#             {
#
#                 "rank": 195,
#
#                 "pmid": "21141905",
#
#                 "score": 91.81285095214844
#
#             }
#
#         ]
#
#     }
#
# ]

# %%
include, exclude, maybe =  categorize_documents_by_judgment("ranking_pages_feedback.json")

# %%
include
# Out:
# [{'rank': 1,
#   'pmid': '23471324',
#   'title': 'Effect of aspherical and yellow tinted intraocular lens on blue-on-yellow perimetry.',
#   'relevance': 'include'},
#  {'rank': 2,
#   'pmid': '16631056',
#   'title': 'Visual performance: Comparison of foldable intraocular lenses.',
#   'relevance': 'include'},
#  {'rank': 8,
#   'pmid': '17444040',
#   'title': '[The clinical investigation of early visual function in cataract patients after implantation with aspheric intraocular lens].',
#   'relevance': 'include'},
#  {'rank': 9,
#   'pmid': '22108107',
#   'title': 'Effects of blue light-filtering intraocular lenses on the macula, contrast sensitivity, and color vision after a long-term follow-up.',
#   'relevance': 'include'},
#  {'rank': 10,
#   'pmid': '23461152',
#   'title': '[Evaluation of colour vision according to type of implanted artificial foldable intraocular lens].',
#   'relevance': 'include'},
#  {'rank': 11,
#   'pmid': '26096521',
#   'title': 'Influence of light filters in intraocular lenses on color perception and contrast acuity.',
#   'relevance': 'include'},
#  {'rank': 13,
#   'pmid': '19101429',
#   'title': 'Effect of a blue-light-blocking intraocular lens on the quality of sleep.',
#   'relevance': 'include'}]

# %%
df = create_dataframe(include, exclude, maybe)

# %%
df
# Out:
#     rank      pmid                                              title  \
# 0      1  23471324  Effect of aspherical and yellow tinted intraoc...
# 1      2  16631056  Visual performance: Comparison of foldable int...
# 2      8  17444040  [The clinical investigation of early visual fu...
# 3      9  22108107  Effects of blue light-filtering intraocular le...
# 4     10  23461152  [Evaluation of colour vision according to type...
# 5     11  26096521  Influence of light filters in intraocular lens...
# 6     13  19101429  Effect of a blue-light-blocking intraocular le...
# 7      3  19575919  [Comparison of contrast sensitivity and wavefr...
# 8      4  16473225  AcrySof Natural SN60AT versus AcrySof SA60AT i...
# 9      5  17056369  Frequency doubling technology perimetry after ...
# 10     6  16338566  Quality-of-life improvements in cataract patie...
# 11     7  18191090  Blue light-filter intraocular lenses in vitrec...
# 12    14  27966269  The effect of blue-blocking and neutral intrao...
# 13    15  16597662  Visual function in patients with yellow tinted...
# 14    16  16863969  Effect of the AcrySof Natural intraocular lens...
# 15    17  21350691  The effect of yellow tinted intraocular lenses...
# 16    18  16445445  Colour vision and retinal nerve fibre layer ph...
# 17    19  19118695  Influence of blue-light-filtering intraocular ...
# 18    20  18471631  Intraindividual comparison of color contrast s...
# 19    21  17397731  Contrast sensitivity and glare disability afte...
# 20    22  24756476  Blue light-filtering intraocular lenses and po...
# 21    25  18361983  Intraindividual comparison of a blue-light fil...
# 22    12  17867510  [The observation of visual quality after the i...
# 23    23  19304088  Objective assessment of inflammation after cat...
# 24    24  19333692  All-distance visual acuity in eyes with a nont...
#
#    relevance
# 0    include
# 1    include
# 2    include
# 3    include
# 4    include
# 5    include
# 6    include
# 7    exclude
# 8    exclude
# 9    exclude
# 10   exclude
# 11   exclude
# 12   exclude
# 13   exclude
# 14   exclude
# 15   exclude
# 16   exclude
# 17   exclude
# 18   exclude
# 19   exclude
# 20   exclude
# 21   exclude
# 22     maybe
# 23     maybe
# 24     maybe

# %% [markdown]
# 4. Function/API route
# read ranking_pages and output to nbib format

# %%
pmid_to_title = pmid_to_title_mapping('corpus.json')

# %%
pmid_to_title
# Out:
# {'24065808': 'High resolution OCT quantitative analysis of the space between the IOL and the posterior capsule during the early cataract postoperative period.',
#  '20610091': 'Islands of lens epithelial cells on the posterior capsule in pseudophakic eyes.',
#  '24158845': 'New light for old eyes: comparing melanopsin-mediated non-visual benefits of blue-light and UV-blocking intraocular lenses.',
#  '24756476': 'Blue light-filtering intraocular lenses and post-operative mood: a pilot clinical study.',
#  '27432203': 'Chromatic Multifocal Pupillometer for Objective Perimetry and Diagnosis of Patients with Retinitis Pigmentosa.',
#  '23882696': 'Characterization of stargardt disease using polarization-sensitive optical coherence tomography and fundus autofluorescence imaging.',
#  '16863969': 'Effect of the AcrySof Natural intraocular lens on blue-yellow perimetry.',
#  '18581789': 'Contrast sensitivity and higher order aberrations in eyes implanted with AcrySof IQ SN60WF and AcrySof SN60AT intraocular lenses.',
#  '1087839': 'A possible change of refractive index with age and its relevance to chromatic aberration.',
#  '12614752': 'Clinicopathologic study after submacular removal of choroidal neovascular membranes treated with verteporfin ocular photodynamic therapy.',
#  '19118695': 'Influence of blue-light-filtering intraocular lenses on color perception and contrast acuity.',
#  '22732187': 'Lutein and zeaxanthin supplementation reduces photooxidative damage and modulates the expression of inflammation-related genes in retinal pigment epithelial cells.',
#  '17056369': 'Frequency doubling technology perimetry after clear and yellow intraocular lens implantation.',
#  '18404118': '[Aberrometry and contrast sensitivity after cataract surgery: aspherical IOL evaluation].',
#  '17867510': '[The observation of visual quality after the implantation of apodized diffractive multifocal intraocular lens].',
#  '26096521': 'Influence of light filters in intraocular lenses on color perception and contrast acuity.',
#  '21350691': 'The effect of yellow tinted intraocular lenses on the result of frequency doubling perimetry after cataract surgery.',
#  '15682919': 'Comparing the contrast sensitivity of a modified prolate anterior surface IOL and of two spherical IOLs.',
#  '16792735': 'Supplementation with the carotenoids lutein or zeaxanthin improves human visual performance.',
#  '3883964': 'Near-UV radiation from the operating microscope and pseudophakic cystoid macular edema.',
#  '16834830': "The economic impact of blue-light filtering intraocular lenses on age-related macular degeneration associated with cataract surgery: a third-party payer's perspective.",
#  '18856236': 'Postoperative optical aberrations in eyes implanted with AcrySof spherical and aspheric intraocular lenses.',
#  '17397740': 'Effect of a yellow intraocular lens on scotopic vision, glare disability, and blue color perception.',
#  '21641040': 'Macular pigment changes in pseudophakic eyes quantified with resonance Raman spectroscopy.',
#  '17260315': '[Visual function with blue light filter IOLs].',
#  '16473224': 'Clinical results of the blue-light filtering AcrySof Natural foldable acrylic intraocular lens.',
#  '18195239': 'Sterile endophthalmitis after benzyl alcohol filtered triamcinolone acetonide injection.',
#  '17469752': 'Blue light filtering intraocular lenses in phacoemulsification cataract surgery.',
#  '3991126': 'Effect of an ultraviolet-filtering intraocular lens on cystoid macular edema.',
#  '28676040': 'Congenital aniridia with cataract: case series.',
#  '28002333': 'Impact of blue-light filtering intraocular lens implantation on the quality of sleep in patients after cataract surgery.',
#  '17159440': 'Is cataract surgery a risk factor for progression of macular degeneration?',
#  '22858061': 'Effect of primary posterior continuous curvilinear capsulorrhexis with posterior optic buttonholing on pilocarpine-induced IOL shift.',
#  '18850550': 'Comparison of higher order aberrations with spherical and aspheric IOLs compared to normal phakic eyes.',
#  '25582206': '[The effect of blue light on human retinal pigment epithelium cells α1D subunit protein expression and vascular endothelial growth factor and basic fibroblast growth factor secretion in vitro].',
#  '19304086': 'Wavefront aberrations, depth of focus, and contrast sensitivity with aspheric and spherical intraocular lenses: fellow-eye study.',
#  '24269140': 'Light transmittance of 1-piece hydrophobic acrylic intraocular lenses with surface light scattering removed from cadaver eyes.',
#  '21951571': 'Reaction time as a measure of enhanced blue-light mediated cognitive function following cataract surgery.',
#  '19410947': 'Visual acuity and contrast sensitivity in eyes implanted with aspheric and spherical intraocular lenses.',
#  '20202534': 'Color discrimination by patients with different types of light-filtering intraocular lenses.',
#  '22594975': 'High refractive index polysiloxane as injectable, in situ curable accommodating intraocular lens.',
#  '17362457': 'Comparison of visual function following implantation of Acrysof Natural intraocular lenses with conventional intraocular lenses.',
#  '1788533': 'Ocular exposure to solar ultraviolet and visible radiation at high latitudes.',
#  '20665986': 'Clinical study of Acrysof IQ aspheric intraocular lenses.',
#  '19304088': 'Objective assessment of inflammation after cataract surgery: comparison of 3 similar intraocular lens models.',
#  '19251148': 'Relative effectiveness of a blue light-filtering intraocular lens for photoentrainment of the circadian rhythm.',
#  '18988171': 'Clinical evaluation of the use of infracyanine green staining for internal limiting membrane peeling in epimacular membrane surgery.',
#  '23471324': 'Effect of aspherical and yellow tinted intraocular lens on blue-on-yellow perimetry.',
#  '8745513': 'Fine matrix mapping of the macular region in normal subjects.',
#  '19545814': 'Comparison of the incidence and visual significance of posterior capsule opacification between multifocal spherical, monofocal spherical, and monofocal aspheric intraocular lenses.',
#  '16564998': 'Color perception with AcrySof natural and AcrySof single-piece intraocular lenses under photopic and mesopic conditions.',
#  '18361983': 'Intraindividual comparison of a blue-light filter on visual function: AF-1 (UY) versus AF-1 (UV) intraocular lens.',
#  '21856011': 'Determination of valid benchmarks for outcome indicators in cataract surgery: a multicenter, prospective cohort trial.',
#  '23472744': 'Functional and perceived benefits of wearing coloured filters by patients with age-related macular degeneration.',
#  '1794814': '[Effect of cut off filters on contrast perception in retinitis pigmentosa].',
#  '3211494': 'Medical management of a high bleb phase after trabeculectomies.',
#  '17444040': '[The clinical investigation of early visual function in cataract patients after implantation with aspheric intraocular lens].',
#  '17534810': 'A comparison of higher order aberrations in eyes implanted with AcrySof IQ SN60WF and AcrySof SN60AT intraocular lenses.',
#  '3466465': 'Visual performance in pseudophakia with standard and ultraviolet-absorbing intraocular lenses: a preliminary report.',
#  '19628740': 'Augmentation of macular pigment following implantation of blue light-filtering intraocular lenses at the time of cataract surgery.',
#  '19700536': 'Collimator with filtration compensator: clinical adaptation to meet European Union recommendation 4F on radiological protection for dental radiography.',
#  '26074032': 'Differential monocular vs. binocular pupil responses from melanopsin-based photoreception in patients with anterior ischemic optic neuropathy.',
#  '22205829': 'Correlation between contrast sensitivity and higher-order aberration based on pupil diameter after cataract surgery.',
#  '22520306': 'Visual quality assessment in patients with orange-tinted blue light-filtering and clear ultraviolet light-filtering intraocular lenses.',
#  '14724954': '[Study of blue light induced DNA damage of retinal pigment epithelium(RPE) cells and the protection of vitamin C].',
#  '20355006': 'Effects of lutein and zeaxanthin on aspects of eye health.',
#  '8060925': 'Increased prevalence of disciform macular degeneration after cataract extraction with implantation of an intraocular lens.',
#  '17420703': 'Effect of tinted optical filters on visual acuity and contrast sensitivity in patients with inflammatory cystoid macular edema.',
#  '25216318': 'Do blue-light filtering intraocular lenses affect visual function?',
#  '3454916': 'Foveal and non-foveal measures of short wavelength sensitive pathways in glaucoma and ocular hypertension.',
#  '25680758': 'Photochemical approaches to vision restoration.',
#  '22108107': 'Effects of blue light-filtering intraocular lenses on the macula, contrast sensitivity, and color vision after a long-term follow-up.',
#  '18075744': '[Lutein and antioxidants in the prevention of age-related macular degeneration].',
#  '27256717': 'Dexamethasone intravitreal implant in serpiginous choroiditis.',
#  '21111309': 'Comparison of visual performance with blue light-filtering and ultraviolet light-filtering intraocular lenses.',
#  '27464575': 'Blue and Red Light-Evoked Pupil Responses in Photophobic Subjects with TBI.',
#  '22412976': 'Comparison of blue light-filtering IOLs and UV light-filtering IOLs for cataract surgery: a meta-analysis.',
#  '19781467': 'Feasibility of spherical aberration correction with aspheric intraocular lenses in cataract surgery based on individual pupil diameter.',
#  '21111310': 'Comparison of photochromic, yellow, and clear intraocular lenses in human eyes under photopic and mesopic lighting conditions.',
#  '3454917': 'Psychophysical measurement of the foveal avascular zone.',
#  '15702781': '[The effect of blue light on mitochondrial membrane potential and cytochrome C of cultured human retinal pigment epithelium cells].',
#  '9790588': 'Isolation and characterization of homologues of plant blue-light photoreceptor (cryptochrome) genes from the fern Adiantum capillus-veneris.',
#  '24021181': '[The protective effect of photochromic intraocular lens on visible light-induced lesion in cultured retinal pigment epithelium].',
#  '17964398': 'Ocular aberrations and contrast sensitivity after cataract surgery with AcrySof IQ intraocular lens implantation Clinical comparative study.',
#  '18464801': 'Objective and subjective outcomes in comparing three different aspheric intraocular lens implants with their spherical counterparts.',
#  '16445446': 'Visual outcomes with the yellow intraocular lens.',
#  '22287168': 'Contrast sensitivity and color perception with orange and yellow intraocular lenses.',
#  '23776409': 'Co-expression of VAL- and TMT-opsins uncovers ancient photosensory interneurons and motorneurons in the vertebrate brain.',
#  '25838942': 'Attenuating Photostress and Glare Disability in Pseudophakic Patients through the Addition of a Short-Wave Absorbing Filter.',
#  '26478261': 'Comparison of acute non-visual bright light responses in patients with optic nerve disease, glaucoma and healthy controls.',
#  '22952402': 'Comparison of posterior capsule opacification between a 1-piece and a 3-piece microincision intraocular lens.',
#  '18976313': 'Ocular wavefront analysis and contrast sensitivity in eyes implanted with AcrySof IQ or AcrySof Natural intraocular lenses.',
#  '23211814': 'Glare disability, photostress recovery, and chromatic contrast: relation to macular pigment and serum lutein and zeaxanthin.',
#  '21752591': 'Comparison of color perception after tinted blue light-filtering and clear ultraviolet-filtering intraocular lens implantation.',
#  '25223707': 'Autofluorescence imaging of macular pigment: influence and correction of ocular media opacities.',
#  '23074519': 'Intraocular lenses for the treatment of age-related cataracts: an evidence-based analysis.',
#  '22744386': 'Internal spherical aberration by ray tracing-type aberrometry in multifocal pseudophakic eyes.',
#  '26286756': 'Effect on contrast sensitivity after clear, yellow and orange intraocular lens implantation.',
#  '12411437': 'Intramolecular proton transfers and structural changes during the photocycle of the LOV2 domain of phototropin 1.',
#  '27420965': 'Establishment of a blue light damage model of human retinal pigment epithelial cells in vitro.',
#  '26708928': 'Protective Effect of Fucoxanthin Isolated from Laminaria japonica against Visible Light-Induced Retinal Damage Both in Vitro and in Vivo.',
#  '22653894': 'Does pupil constriction under blue and green monochromatic light exposure change with age?',
#  '25968007': 'The effect of blue-blocking intraocular lenses on circadian biological rhythm: protocol for a randomised controlled trial (CLOCK-IOL colour study).',
#  '21886359': 'Sleep disturbances are related to decreased transmission of blue light to the retina caused by lens yellowing.',
#  '4437543': 'The spectral curve of relative luminous efficiency in different age groups of aphakic eyes.',
#  '2589059': 'Do intraocular lenses with ultraviolet absorbing chromophores protect against macular oedema?',
#  '23608567': 'Fellow-eye comparison of posterior capsule opacification between 2 aspheric microincision intraocular lenses.',
#  '22067557': 'Effect of intraocular lens asphericity on posterior capsule opacification between two intraocular lenses with same acrylic material: a fellow-eye study.',
#  '18191090': 'Blue light-filter intraocular lenses in vitrectomy combined with cataract surgery: results of a randomized controlled clinical trial.',
#  '21455768': 'Cone function in children with a history of preterm birth.',
#  '24205001': 'Contrast sensitivity and spherical aberration in eyes implanted with AcrySof IQ and AcrySof Natural intraocular lens: the results of a meta-analysis.',
#  '16597662': 'Visual function in patients with yellow tinted intraocular lenses compared with vision in patients with non-tinted intraocular lenses.',
#  '21111307': 'Clinical evaluation of the transparency of hydrophobic acrylic intraocular lens optics.',
#  '19575919': '[Comparison of contrast sensitivity and wavefront analysis after implantation of AcrySof IQ aspherical intraocular lens].',
#  '15606466': 'The effects of coloured light filter overlays on reading rates in age-related macular degeneration.',
#  '24970263': 'Impact of cataract surgery on sleep in patients receiving either ultraviolet-blocking or blue-filtering intraocular lens implants.',
#  '24597610': 'Effects of a chronic reduction of short-wavelength light input on melatonin and sleep patterns in humans: evidence for adaptation.',
#  '22727284': 'Incidence of glistenings with the latest generation of yellow-tinted hydrophobic acrylic intraocular lenses.',
#  '16473225': 'AcrySof Natural SN60AT versus AcrySof SA60AT intraocular lens in patients with color vision defects.',
#  '7920190': 'Tinting effect of ultraviolet radiation on intraocular lenses of polymethyl methacrylate.',
#  '14687197': 'Effect of light filters on reading speed in normal and low vision due to age-related macular degeneration.',
#  '26968411': 'Effect of blue light-filtering intraocular lens on color vision in patients with macular diseases after vitrectomy.',
#  '21094670': 'Impact of blue vs red light on retinal response of patients with seasonal affective disorder and healthy controls.',
#  '11260499': 'Genetic dissection of blue-light sensing in tomato using mutants deficient in cryptochrome 1 and phytochromes A, B1 and B2.',
#  '27966269': 'The effect of blue-blocking and neutral intraocular lenses on circadian photoentrainment and sleep one year after cataract surgery.',
#  '16445433': 'Age-related maculopathy and the impact of blue light hazard.',
#  '27380430': 'RETICULAR PSEUDODRUSEN ARE NOT A PREDICTIVE FACTOR FOR THE 1-YEAR RESPONSE TO INTRAVITREAL RANIBIZUMAB IN NEOVASCULAR AGE-RELATED MACULAR DEGENERATION.',
#  '26491964': 'Diversity of Active States in TMT Opsins.',
#  '19491981': 'Comparison of pseudophakic visual quality in spherical and aspherical intraocular lenses.',
#  '23742627': 'Early changes in gene expression induced by blue light irradiation of A2E-laden retinal pigment epithelial cells.',
#  '17397731': 'Contrast sensitivity and glare disability after implantation of AcrySof IQ Natural aspherical intraocular lens: prospective randomized masked clinical trial.',
#  '25103657': 'A simple method to shorten the unfolding time of prehydrated hydrophobic intraocular lens.',
#  '22864026': 'Trypan blue staining of filtering bleb in eyes with operate trabeculectomy.',
#  '7514581': 'Iris pigmentation and extent of disease in patients with neovascular age-related macular degeneration.',
#  '22762040': 'Protective effect of saturated hydrogen saline against blue light-induced retinal damage in rats.',
#  '15234295': 'Contrast sensitivity and color vision with a yellow intraocular len.',
#  '11553757': 'shl, a New set of Arabidopsis mutants with exaggerated developmental responses to available red, far-red, and blue light.',
#  '16755682': 'Clinical evaluation of the use of indocyanine green for peeling the internal limiting membrane in macular hole surgery.',
#  '15662502': '[Influence of cutoff filters on reading behavior in age-related macular degeneration].',
#  '28155996': 'Anti-apoptotic effects of Curcuma longa L. extract and its curcuminoids against blue light-induced cytotoxicity in A2E-laden human retinal pigment epithelial cells.',
#  '2748876': 'Antidepressant medication reverses increased sensitivity to light in depression: preliminary report.',
#  '19643497': 'Effect of intraocular lens asphericity on quality of vision after cataract removal: an intraindividual comparison.',
#  '28264100': 'The Relation Between Light-Induced Lacrimation and the Melanopsin-Driven Postillumination Pupil Response.',
#  '8871173': 'Acetazolamide affects performance on the Nagel II anomaloscope.',
#  '27580077': "Blue-Black or White-Gold? Early Stage Processing and the Color of 'The Dress'.",
#  '21883771': 'Differential effect of long versus short wavelength light exposure on pupillary re-dilation in patients with outer retinal disease.',
#  '27935597': "The evidence informing the surgeon's selection of intraocular lens on the basis of light transmittance properties.",
#  '15852166': '[Intraocular lenses with blue light filter].',
#  '16445445': 'Colour vision and retinal nerve fibre layer photography in patients with an Acrysof Natural intraocular lens.',
#  '19629514': 'Prospective, randomized, controlled clinical study evaluating the efficacy of Rheopheresis for dry age-related macular degeneration. Dry AMD treatment with Rheopheresis Trial-ART.',
#  '19140849': 'A case report of double-filtration plasmapheresis for the treatment of age-related macular degeneration.',
#  '15705234': 'Fasting plasma zeaxanthin response to Fructus barbarum L. (wolfberry; Kei Tze) in a food-based human supplementation trial.',
#  '23461152': '[Evaluation of colour vision according to type of implanted artificial foldable intraocular lens].',
#  '27226262': 'Blue-blocking glasses as additive treatment for mania: a randomized placebo-controlled trial.',
#  '15870573': 'Light energy, cataract surgery, and progression of age-related macular degeneration.',
#  '22527312': 'Iris color and visual functions.',
#  '15988925': 'Study of blue and red flash in dark-adapted electroretinogram.',
#  '20030543': 'Amber lenses to block blue light and improve sleep: a randomized trial.',
#  '15302349': 'Do blue light filters confer protection against age-related macular degeneration?',
#  '2596543': 'The influence of decreased retinal illumination on automated perimetric threshold measurements.',
#  '26589689': 'Preventive effect of Vaccinium uliginosum L. extract and its fractions on age-related macular degeneration and its action mechanisms.',
#  '17416326': 'Surgical findings with the tinted AcrySof intraocular lens in children.',
#  '16338566': 'Quality-of-life improvements in cataract patients with bilateral blue light-filtering intraocular lenses: clinical trial.',
#  '18721708': 'Fellow-eye comparison of posterior capsule opacification with AcrySof SN60AT and AF-1 YA-60BB blue-blocking intraocular lenses.',
#  '26850586': '[The correlation between the concentrations of VEGF and PEDF and Ca2+-PKC signaling pathways in human retinal pigment epithelial cells cultured in vitro after exposuring to blue light].',
#  '3772782': 'Particulate and microbial contamination of intraocular irrigation solutions.',
#  '19576065': '[The clinical investigation of dynamic changes of corneal astigmatism and visual quality for patients after phacoemulsification surgery through different incision and implantation of different designed intraocular lens].',
#  '24771157': 'A new IOL with labeled accurate dioptric powers reduces the postoperative refractive error.',
#  '17912933': 'Prospective randomized study of clinical performance of 3 aspheric and 2 spherical intraocular lenses in 250 eyes.',
#  '22139617': 'In vivo assessment of higher-order aberrations after AcrySof toric intraocular lens implantation: a comparative study.',
#  '24009749': 'The effect of lutein supplementation on blood plasma levels of complement factor D, C5a and C3d.',
#  '15093654': 'Blue light-absorbing intraocular lens and retinal pigment epithelium protection in vitro.',
#  '22321501': '[Clinical observation of visual quality after implantation of toric intraocular lens].',
#  '14769042': 'Selectivity of retinal photoisomerization in proteorhodopsin is controlled by aspartic acid 227.',
#  '21141905': 'Tripping the light fantastic: blue-light photoreceptors as examples of environmentally modulated protein-protein interactions.',
#  '25612055': 'Impact of a Digital Power Line Filter in the 2-Global-Flash Multifocal Electroretinogram of Glaucoma Patients Compared to Controls.',
#  '16631056': 'Visual performance: Comparison of foldable intraocular lenses.',
#  '19820794': 'Comparison between OPD-Scan results and visual outcomes of monofocal and multifocal intraocular lenses.',
#  '17084803': 'Xanthophyll accumulation in the human retina during supplementation with lutein or zeaxanthin - the LUXEA (LUtein Xanthophyll Eye Accumulation) study.',
#  '23467788': 'Astigmatism correction with toric intraocular lenses: wavefront aberrometry and quality of life.',
#  '21950699': 'Influence of blue light-filtering intraocular lenses on retinal nerve fiber layer measurements by spectral-domain optical coherence tomography.',
#  '12877897': 'Clinical studies to implement Rheopheresis for age-related macular degeneration guided by evidence-based-medicine.',
#  '18361993': 'Edge profile of commercially available square-edged intraocular lenses.',
#  '19333692': 'All-distance visual acuity in eyes with a nontinted or a yellow-tinted diffractive multifocal intraocular lens.',
#  '26233628': 'The Effect of Cataract Surgery on Circadian Photoentrainment: A Randomized Trial of Blue-Blocking versus Neutral Intraocular Lenses.',
#  '19662914': 'Contrast sensitivity evaluation of aspheric and spherical intraocular lenses 2 years after implantation.',
#  '26471051': 'Prevention of increased abnormal fundus autofluorescence with blue light-filtering intraocular lenses.',
#  '18471631': 'Intraindividual comparison of color contrast sensitivity in patients with clear and blue-light-filtering intraocular lenses.',
#  '18320254': 'Zeaxanthin is bioavailable from genetically modified zeaxanthin-rich potatoes.',
#  '17445897': 'Spherical aberration and depth of focus in eyes implanted with aspheric and spherical intraocular lenses: a prospective randomized study.',
#  '10809448': 'Tomato contains homologues of Arabidopsis cryptochromes 1 and 2.',
#  '27785596': 'The diagnostic accuracy of chromatic pupillary light responses in diseases of the outer and inner retina.',
#  '19896637': 'Ability of new vital dyes to stain intraocular membranes and tissues in ocular surgery.',
#  '21183103': 'Visual axis opacification after cataract surgery and hydrophobic acrylic intraocular lens implantation in the first year of life.',
#  '19101429': 'Effect of a blue-light-blocking intraocular lens on the quality of sleep.'}

# %%
export_by_judgment(include, 'include', 'demo.ris', 'included_studies.ris')

# %% [markdown]
# Core: generate new ranking_pages based on feedback from previous pages

# %%
import numpy as np
import pandas as pd
from typing import List, Dict
from pyserini.search import FaissSearcher
from rf_rocchio import RocchioRf
from faiss import read_index


class InteractiveRanker:
    def __init__(self, model_path: str, index_path: str, query_embedding_path: str,
                 rocchio_params: List[float] = [1.0, 1.0, 1.0]):
        self.model_path = model_path
        
        if len(rocchio_params) != 3:
            raise ValueError("rocchio_params must be a list of 3 float values [alpha, beta, gamma]")

        self.alpha, self.beta, self.gamma = rocchio_params

        self.searcher = FaissSearcher(index_path, model_path)
        
        self.index = read_index(f"{index_path}/index")

        # Load query embedding
        self.query_embedding = pd.read_pickle(query_embedding_path)[0]
        if len(self.query_embedding.shape) == 1:
            self.query_embedding = self.query_embedding.reshape((1, len(self.query_embedding)))
        

    def generate_ranking_pages(self, feedback_data: Dict, feedback_size: int = 10) -> Dict:
        # Process feedback for Rocchio
        rocchio_feedback = []
        doc_idx_list = self.searcher.docids
        
        for doc in feedback_data['in_page_docs']:
            doc_idx = doc_idx_list.index(doc['pmid'])
            doc_vector = self.index.reconstruct(doc_idx)
            rocchio_feedback.append({
                'docid': doc['pmid'],
                'score': doc['score'],
                'vectors': doc_vector,
                'feedback': doc['feedback']  # Now directly using 'include', 'exclude', or 'maybe'
            })
            

        # Perform relevance feedback
        rocchio_rf = RocchioRf(alpha=self.alpha, beta=self.beta, gamma=self.gamma,
                               top_k=len(feedback_data['in_page_docs']))

        new_query_embedding = rocchio_rf.get_rf_q_emb(self.query_embedding, rf_candidates=rocchio_feedback)

        if len(new_query_embedding.shape) == 1:
            new_query_embedding = new_query_embedding.reshape((1, len(new_query_embedding)))

        self.query_embedding = new_query_embedding

        # Get the list of PMIDs from remaining_ranking
        remaining_pmids = [doc['pmid'] for doc in feedback_data['remaining_ranking']]

        # Rerank the remaining documents
        reranked_docs = []
        for pmid in remaining_pmids:
            doc_idx = doc_idx_list.index(pmid)
            doc_vector = self.index.reconstruct(doc_idx)
            score = np.dot(self.query_embedding, doc_vector)[0]
            reranked_docs.append((pmid, score))

        # Sort the reranked documents by score
        reranked_docs.sort(key=lambda x: x[1], reverse=True)

        # Prepare new ranking
        in_page_docs = []
        remaining_ranking = []

        for rank, (pmid, score) in enumerate(reranked_docs, start=1):

            if rank <= feedback_size:
                doc_info = {
                "rank": rank,
                "pmid": pmid,
                "score": float(score),
                "feedback": "unjudged (default)",
            }
                in_page_docs.append(doc_info)
            else:
                doc_info = {
                "rank": rank,
                "pmid": pmid,
                "score": float(score),
            }
                remaining_ranking.append(doc_info)

        return {
            "type": "dense_rocchio",
            "in_page_docs": in_page_docs,
            "remaining_ranking": remaining_ranking
        }

# %%
ranker = InteractiveRanker(
        model_path="trained_models/clef19_intervention/biolinkbert_128_256_11",
        index_path="indexes/clef19_intervention/",
        query_embedding_path="tevatron_queries_encode/clef19_intervention/biolinkbert_128_256_11/clef19_intervention_query_pico.pkl",
        rocchio_params=[1.0, 1.0, 1.0]  # [alpha, beta, gamma]
    )
# Out:
# /opt/anaconda3/envs/infs7410/lib/python3.8/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
import json

previous_ranking_page = json.load(open('fixed_ranking_pages_feedback.json'))
previous_ranking_page
# Out:
# [{'type': 'init_ranking',
#   'ranking_at': '',
#   'in_page_docs': [{'rank': 1,
#     'pmid': '23471324',
#     'score': 132.36045837402344,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 2,
#     'pmid': '16631056',
#     'score': 131.1927490234375,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 3,
#     'pmid': '19575919',
#     'score': 130.38162231445312,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 4,
#     'pmid': '16473225',
#     'score': 130.22390747070312,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 5,
#     'pmid': '17056369',
#     'score': 130.19273376464844,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 6,
#     'pmid': '16338566',
#     'score': 129.77841186523438,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 7,
#     'pmid': '18191090',
#     'score': 129.64715576171875,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 8,
#     'pmid': '17444040',
#     'score': 129.6131591796875,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 9,
#     'pmid': '22108107',
#     'score': 129.3938446044922,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 10,
#     'pmid': '23461152',
#     'score': 129.33865356445312,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 11,
#     'pmid': '26096521',
#     'score': 129.23013305664062,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 12,
#     'pmid': '17867510',
#     'score': 129.2013702392578,
#     'feedback': 'maybe',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 13,
#     'pmid': '19101429',
#     'score': 129.00082397460938,
#     'feedback': 'include',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 14,
#     'pmid': '27966269',
#     'score': 128.94635009765625,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 15,
#     'pmid': '16597662',
#     'score': 128.94204711914062,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 16,
#     'pmid': '16863969',
#     'score': 128.84152221679688,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 17,
#     'pmid': '21350691',
#     'score': 128.8072052001953,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 18,
#     'pmid': '16445445',
#     'score': 128.78982543945312,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 19,
#     'pmid': '19118695',
#     'score': 128.72802734375,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 20,
#     'pmid': '18471631',
#     'score': 128.63986206054688,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 21,
#     'pmid': '17397731',
#     'score': 128.57127380371094,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 22,
#     'pmid': '24756476',
#     'score': 128.52505493164062,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 23,
#     'pmid': '19304088',
#     'score': 128.40782165527344,
#     'feedback': 'maybe',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 24,
#     'pmid': '19333692',
#     'score': 128.3487091064453,
#     'feedback': 'maybe',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'},
#    {'rank': 25,
#     'pmid': '18361983',
#     'score': 128.29364013671875,
#     'feedback': 'exclude',
#     'feedback_created_at': 'yyyy-mm-ddThhmm.ss+00.00',
#     'feedback_updated_at': 'yyyy-mm-ddThhmm.ss+00.00'}],
#   'remaining_ranking': [{'rank': 26,
#     'pmid': '21111309',
#     'score': 128.10885620117188},
#    {'rank': 27, 'pmid': '17964398', 'score': 128.0149688720703},
#    {'rank': 28, 'pmid': '22287168', 'score': 127.90097045898438},
#    {'rank': 29, 'pmid': '22520306', 'score': 127.87181091308594},
#    {'rank': 30, 'pmid': '20665986', 'score': 127.86184692382812},
#    {'rank': 31, 'pmid': '15234295', 'score': 127.78459930419922},
#    {'rank': 32, 'pmid': '19643497', 'score': 127.768310546875},
#    {'rank': 33, 'pmid': '26286756', 'score': 127.76782989501953},
#    {'rank': 34, 'pmid': '25838942', 'score': 127.67823028564453},
#    {'rank': 35, 'pmid': '25216318', 'score': 127.46647644042969},
#    {'rank': 36, 'pmid': '19662914', 'score': 127.40303039550781},
#    {'rank': 37, 'pmid': '19820794', 'score': 127.37431335449219},
#    {'rank': 38, 'pmid': '18464801', 'score': 127.23814392089844},
#    {'rank': 39, 'pmid': '19410947', 'score': 127.18842315673828},
#    {'rank': 40, 'pmid': '15852166', 'score': 127.03942108154297},
#    {'rank': 41, 'pmid': '18721708', 'score': 126.98091125488281},
#    {'rank': 42, 'pmid': '19576065', 'score': 126.93975830078125},
#    {'rank': 43, 'pmid': '21752591', 'score': 126.87960815429688},
#    {'rank': 44, 'pmid': '17912933', 'score': 126.84327697753906},
#    {'rank': 45, 'pmid': '22727284', 'score': 126.78041076660156},
#    {'rank': 46, 'pmid': '22952402', 'score': 126.73774719238281},
#    {'rank': 47, 'pmid': '22321501', 'score': 126.6017074584961},
#    {'rank': 48, 'pmid': '18404118', 'score': 126.513916015625},
#    {'rank': 49, 'pmid': '15682919', 'score': 126.45832824707031},
#    {'rank': 50, 'pmid': '22067557', 'score': 126.44808959960938},
#    {'rank': 51, 'pmid': '16564998', 'score': 126.41815948486328},
#    {'rank': 52, 'pmid': '17362457', 'score': 126.36015319824219},
#    {'rank': 53, 'pmid': '24021181', 'score': 126.34976196289062},
#    {'rank': 54, 'pmid': '23608567', 'score': 126.32183074951172},
#    {'rank': 55, 'pmid': '17260315', 'score': 126.27311706542969},
#    {'rank': 56, 'pmid': '21183103', 'score': 126.25241088867188},
#    {'rank': 57, 'pmid': '15606466', 'score': 126.20354461669922},
#    {'rank': 58, 'pmid': '26233628', 'score': 126.18363952636719},
#    {'rank': 59, 'pmid': '16445446', 'score': 126.14916229248047},
#    {'rank': 60, 'pmid': '26968411', 'score': 126.118408203125},
#    {'rank': 61, 'pmid': '19491981', 'score': 126.11793518066406},
#    {'rank': 62, 'pmid': '17469752', 'score': 125.99193572998047},
#    {'rank': 63, 'pmid': '28676040', 'score': 125.94467163085938},
#    {'rank': 64, 'pmid': '28002333', 'score': 125.93553161621094},
#    {'rank': 65, 'pmid': '21950699', 'score': 125.92443084716797},
#    {'rank': 66, 'pmid': '26471051', 'score': 125.87043762207031},
#    {'rank': 67, 'pmid': '17397740', 'score': 125.8631591796875},
#    {'rank': 68, 'pmid': '27935597', 'score': 125.65028381347656},
#    {'rank': 69, 'pmid': '3991126', 'score': 125.5823974609375},
#    {'rank': 70, 'pmid': '23467788', 'score': 125.57616424560547},
#    {'rank': 71, 'pmid': '19545814', 'score': 125.49969482421875},
#    {'rank': 72, 'pmid': '21641040', 'score': 125.4690933227539},
#    {'rank': 73, 'pmid': '17445897', 'score': 125.18612670898438},
#    {'rank': 74, 'pmid': '22205829', 'score': 125.03965759277344},
#    {'rank': 75, 'pmid': '22139617', 'score': 125.0116195678711},
#    {'rank': 76, 'pmid': '22858061', 'score': 124.90310668945312},
#    {'rank': 77, 'pmid': '19304086', 'score': 124.779296875},
#    {'rank': 78, 'pmid': '2589059', 'score': 124.51930236816406},
#    {'rank': 79, 'pmid': '18976313', 'score': 124.3486099243164},
#    {'rank': 80, 'pmid': '17420703', 'score': 124.33673858642578},
#    {'rank': 81, 'pmid': '24269140', 'score': 124.15489959716797},
#    {'rank': 82, 'pmid': '22527312', 'score': 123.91968536376953},
#    {'rank': 83, 'pmid': '20610091', 'score': 123.73002624511719},
#    {'rank': 84, 'pmid': '19781467', 'score': 123.7062759399414},
#    {'rank': 85, 'pmid': '21111310', 'score': 123.64726257324219},
#    {'rank': 86, 'pmid': '16473224', 'score': 123.38107299804688},
#    {'rank': 87, 'pmid': '3883964', 'score': 123.19551086425781},
#    {'rank': 88, 'pmid': '15093654', 'score': 123.10221862792969},
#    {'rank': 89, 'pmid': '24771157', 'score': 122.99810791015625},
#    {'rank': 90, 'pmid': '21856011', 'score': 122.98273468017578},
#    {'rank': 91, 'pmid': '19251148', 'score': 122.9373779296875},
#    {'rank': 92, 'pmid': '24065808', 'score': 122.90177154541016},
#    {'rank': 93, 'pmid': '24205001', 'score': 122.86001586914062},
#    {'rank': 94, 'pmid': '20202534', 'score': 122.64827728271484},
#    {'rank': 95, 'pmid': '19629514', 'score': 122.64456176757812},
#    {'rank': 96, 'pmid': '21111307', 'score': 122.63832092285156},
#    {'rank': 97, 'pmid': '24970263', 'score': 122.56896209716797},
#    {'rank': 98, 'pmid': '17534810', 'score': 122.44052124023438},
#    {'rank': 99, 'pmid': '21883771', 'score': 122.28335571289062},
#    {'rank': 100, 'pmid': '17416326', 'score': 122.07499694824219},
#    {'rank': 101, 'pmid': '24158845', 'score': 121.90252685546875},
#    {'rank': 102, 'pmid': '18856236', 'score': 121.73493957519531},
#    {'rank': 103, 'pmid': '1794814', 'score': 121.70700073242188},
#    {'rank': 104, 'pmid': '15662502', 'score': 121.67713928222656},
#    {'rank': 105, 'pmid': '14687197', 'score': 121.24484252929688},
#    {'rank': 106, 'pmid': '25103657', 'score': 121.15800476074219},
#    {'rank': 107, 'pmid': '1087839', 'score': 121.07058715820312},
#    {'rank': 108, 'pmid': '18850550', 'score': 121.00727081298828},
#    {'rank': 109, 'pmid': '23074519', 'score': 120.89624786376953},
#    {'rank': 110, 'pmid': '22744386', 'score': 120.66741943359375},
#    {'rank': 111, 'pmid': '23211814', 'score': 120.63285827636719},
#    {'rank': 112, 'pmid': '19140849', 'score': 120.52877807617188},
#    {'rank': 113, 'pmid': '17159440', 'score': 120.42298889160156},
#    {'rank': 114, 'pmid': '23472744', 'score': 120.39947509765625},
#    {'rank': 115, 'pmid': '28264100', 'score': 120.37767028808594},
#    {'rank': 116, 'pmid': '3466465', 'score': 120.18171691894531},
#    {'rank': 117, 'pmid': '25612055', 'score': 120.153564453125},
#    {'rank': 118, 'pmid': '27432203', 'score': 120.13245391845703},
#    {'rank': 119, 'pmid': '8060925', 'score': 119.87801361083984},
#    {'rank': 120, 'pmid': '18988171', 'score': 119.7906494140625},
#    {'rank': 121, 'pmid': '22412976', 'score': 119.69992065429688},
#    {'rank': 122, 'pmid': '16755682', 'score': 119.65153503417969},
#    {'rank': 123, 'pmid': '12614752', 'score': 119.63412475585938},
#    {'rank': 124, 'pmid': '18581789', 'score': 119.44100952148438},
#    {'rank': 125, 'pmid': '20030543', 'score': 119.36769104003906},
#    {'rank': 126, 'pmid': '27380430', 'score': 119.20855712890625},
#    {'rank': 127, 'pmid': '7514581', 'score': 118.94424438476562},
#    {'rank': 128, 'pmid': '4437543', 'score': 118.92313385009766},
#    {'rank': 129, 'pmid': '8871173', 'score': 118.88539123535156},
#    {'rank': 130, 'pmid': '17084803', 'score': 118.86241149902344},
#    {'rank': 131, 'pmid': '18361993', 'score': 118.52161407470703},
#    {'rank': 132, 'pmid': '21951571', 'score': 118.48689270019531},
#    {'rank': 133, 'pmid': '24009749', 'score': 118.4853286743164},
#    {'rank': 134, 'pmid': '21455768', 'score': 118.39631652832031},
#    {'rank': 135, 'pmid': '27785596', 'score': 118.38153839111328},
#    {'rank': 136, 'pmid': '25968007', 'score': 118.18231964111328},
#    {'rank': 137, 'pmid': '27256717', 'score': 118.07329559326172},
#    {'rank': 138, 'pmid': '16834830', 'score': 117.96321868896484},
#    {'rank': 139, 'pmid': '27226262', 'score': 117.87645721435547},
#    {'rank': 140, 'pmid': '2748876', 'score': 117.83944702148438},
#    {'rank': 141, 'pmid': '2596543', 'score': 117.63770294189453},
#    {'rank': 142, 'pmid': '7920190', 'score': 117.5777587890625},
#    {'rank': 143, 'pmid': '15870573', 'score': 117.43760681152344},
#    {'rank': 144, 'pmid': '22864026', 'score': 117.33114624023438},
#    {'rank': 145, 'pmid': '26074032', 'score': 116.85218811035156},
#    {'rank': 146, 'pmid': '19628740', 'score': 116.84257507324219},
#    {'rank': 147, 'pmid': '27464575', 'score': 116.5731430053711},
#    {'rank': 148, 'pmid': '21886359', 'score': 116.1737060546875},
#    {'rank': 149, 'pmid': '27420965', 'score': 116.00005340576172},
#    {'rank': 150, 'pmid': '26478261', 'score': 115.94772338867188},
#    {'rank': 151, 'pmid': '22762040', 'score': 114.91752624511719},
#    {'rank': 152, 'pmid': '22732187', 'score': 114.67524719238281},
#    {'rank': 153, 'pmid': '19896637', 'score': 114.64181518554688},
#    {'rank': 154, 'pmid': '14724954', 'score': 114.61380004882812},
#    {'rank': 155, 'pmid': '25582206', 'score': 113.87998962402344},
#    {'rank': 156, 'pmid': '27580077', 'score': 113.55016326904297},
#    {'rank': 157, 'pmid': '8745513', 'score': 113.42311096191406},
#    {'rank': 158, 'pmid': '15988925', 'score': 113.42245483398438},
#    {'rank': 159, 'pmid': '15702781', 'score': 113.01920318603516},
#    {'rank': 160, 'pmid': '23742627', 'score': 112.97728729248047},
#    {'rank': 161, 'pmid': '23882696', 'score': 112.95130157470703},
#    {'rank': 162, 'pmid': '12877897', 'score': 112.75483703613281},
#    {'rank': 163, 'pmid': '3454916', 'score': 112.66812133789062},
#    {'rank': 164, 'pmid': '21094670', 'score': 112.54721069335938},
#    {'rank': 165, 'pmid': '3211494', 'score': 112.04020690917969},
#    {'rank': 166, 'pmid': '3454917', 'score': 111.99664306640625},
#    {'rank': 167, 'pmid': '3772782', 'score': 110.78815460205078},
#    {'rank': 168, 'pmid': '18195239', 'score': 110.307861328125},
#    {'rank': 169, 'pmid': '18075744', 'score': 110.06331634521484},
#    {'rank': 170, 'pmid': '28155996', 'score': 109.59431457519531},
#    {'rank': 171, 'pmid': '16445433', 'score': 109.05743408203125},
#    {'rank': 172, 'pmid': '26589689', 'score': 108.85140991210938},
#    {'rank': 173, 'pmid': '26850586', 'score': 108.55923461914062},
#    {'rank': 174, 'pmid': '25223707', 'score': 108.16583251953125},
#    {'rank': 175, 'pmid': '16792735', 'score': 107.76007080078125},
#    {'rank': 176, 'pmid': '24597610', 'score': 107.40320587158203},
#    {'rank': 177, 'pmid': '19700536', 'score': 107.11094665527344},
#    {'rank': 178, 'pmid': '22653894', 'score': 106.985595703125},
#    {'rank': 179, 'pmid': '22594975', 'score': 106.69032287597656},
#    {'rank': 180, 'pmid': '26708928', 'score': 106.35520935058594},
#    {'rank': 181, 'pmid': '1788533', 'score': 103.6994857788086},
#    {'rank': 182, 'pmid': '15705234', 'score': 103.68241882324219},
#    {'rank': 183, 'pmid': '18320254', 'score': 103.14327239990234},
#    {'rank': 184, 'pmid': '15302349', 'score': 102.7305908203125},
#    {'rank': 185, 'pmid': '26491964', 'score': 102.0655288696289},
#    {'rank': 186, 'pmid': '20355006', 'score': 100.86202239990234},
#    {'rank': 187, 'pmid': '11553757', 'score': 100.58393096923828},
#    {'rank': 188, 'pmid': '23776409', 'score': 98.65303039550781},
#    {'rank': 189, 'pmid': '9790588', 'score': 96.45445251464844},
#    {'rank': 190, 'pmid': '25680758', 'score': 95.01988220214844},
#    {'rank': 191, 'pmid': '14769042', 'score': 94.56123352050781},
#    {'rank': 192, 'pmid': '12411437', 'score': 94.08488464355469},
#    {'rank': 193, 'pmid': '10809448', 'score': 93.08284759521484},
#    {'rank': 194, 'pmid': '11260499', 'score': 92.731201171875},
#    {'rank': 195, 'pmid': '21141905', 'score': 91.81285095214844}]}]

# %%
new_ranking = ranker.generate_ranking_pages(previous_ranking_page[0])
print(new_ranking)
# Out:
# {'type': 'dense_rocchio', 'in_page_docs': [{'rank': 1, 'pmid': '18404118', 'score': 124.2470932006836, 'feedback': 'unjudged (default)'}, {'rank': 2, 'pmid': '26286756', 'score': 124.10676574707031, 'feedback': 'unjudged (default)'}, {'rank': 3, 'pmid': '21111309', 'score': 123.74836730957031, 'feedback': 'unjudged (default)'}, {'rank': 4, 'pmid': '19820794', 'score': 123.70188903808594, 'feedback': 'unjudged (default)'}, {'rank': 5, 'pmid': '24158845', 'score': 123.6377182006836, 'feedback': 'unjudged (default)'}, {'rank': 6, 'pmid': '22520306', 'score': 123.56673431396484, 'feedback': 'unjudged (default)'}, {'rank': 7, 'pmid': '20665986', 'score': 123.47117614746094, 'feedback': 'unjudged (default)'}, {'rank': 8, 'pmid': '17260315', 'score': 123.469970703125, 'feedback': 'unjudged (default)'}, {'rank': 9, 'pmid': '22321501', 'score': 123.31648254394531, 'feedback': 'unjudged (default)'}, {'rank': 10, 'pmid': '28002333', 'score': 122.88048553466797, 'feedback': 'unjudged (default)'}], 'remaining_ranking': [{'rank': 11, 'pmid': '19410947', 'score': 122.78463745117188}, {'rank': 12, 'pmid': '15852166', 'score': 122.78373718261719}, {'rank': 13, 'pmid': '2589059', 'score': 122.62042999267578}, {'rank': 14, 'pmid': '17469752', 'score': 122.496826171875}, {'rank': 15, 'pmid': '26233628', 'score': 122.41779327392578}, {'rank': 16, 'pmid': '15234295', 'score': 122.38320922851562}, {'rank': 17, 'pmid': '19643497', 'score': 122.28903198242188}, {'rank': 18, 'pmid': '28676040', 'score': 122.21205139160156}, {'rank': 19, 'pmid': '19629514', 'score': 122.16008758544922}, {'rank': 20, 'pmid': '3991126', 'score': 122.02294158935547}, {'rank': 21, 'pmid': '18721708', 'score': 121.78462219238281}, {'rank': 22, 'pmid': '24970263', 'score': 121.77533721923828}, {'rank': 23, 'pmid': '21111310', 'score': 121.76628112792969}, {'rank': 24, 'pmid': '22067557', 'score': 121.75483703613281}, {'rank': 25, 'pmid': '17397740', 'score': 121.57555389404297}, {'rank': 26, 'pmid': '25216318', 'score': 121.37037658691406}, {'rank': 27, 'pmid': '26471051', 'score': 121.31986236572266}, {'rank': 28, 'pmid': '22858061', 'score': 121.25555419921875}, {'rank': 29, 'pmid': '22952402', 'score': 121.06291961669922}, {'rank': 30, 'pmid': '17362457', 'score': 120.98968505859375}, {'rank': 31, 'pmid': '22727284', 'score': 120.98174285888672}, {'rank': 32, 'pmid': '3883964', 'score': 120.95787811279297}, {'rank': 33, 'pmid': '21856011', 'score': 120.90601348876953}, {'rank': 34, 'pmid': '17445897', 'score': 120.89348602294922}, {'rank': 35, 'pmid': '17964398', 'score': 120.79519653320312}, {'rank': 36, 'pmid': '19491981', 'score': 120.77775573730469}, {'rank': 37, 'pmid': '22527312', 'score': 120.7475357055664}, {'rank': 38, 'pmid': '15606466', 'score': 120.68659973144531}, {'rank': 39, 'pmid': '18976313', 'score': 120.57725524902344}, {'rank': 40, 'pmid': '19576065', 'score': 120.55841064453125}, {'rank': 41, 'pmid': '22412976', 'score': 120.49459838867188}, {'rank': 42, 'pmid': '15682919', 'score': 120.4833984375}, {'rank': 43, 'pmid': '25838942', 'score': 120.46656036376953}, {'rank': 44, 'pmid': '18464801', 'score': 120.46418762207031}, {'rank': 45, 'pmid': '21641040', 'score': 120.42459869384766}, {'rank': 46, 'pmid': '19545814', 'score': 120.35545349121094}, {'rank': 47, 'pmid': '16564998', 'score': 120.32054901123047}, {'rank': 48, 'pmid': '21183103', 'score': 120.17362213134766}, {'rank': 49, 'pmid': '21752591', 'score': 120.1169204711914}, {'rank': 50, 'pmid': '17416326', 'score': 119.99476623535156}, {'rank': 51, 'pmid': '23608567', 'score': 119.73725891113281}, {'rank': 52, 'pmid': '24021181', 'score': 119.63995361328125}, {'rank': 53, 'pmid': '19304086', 'score': 119.39598083496094}, {'rank': 54, 'pmid': '19781467', 'score': 119.22725677490234}, {'rank': 55, 'pmid': '23467788', 'score': 119.13650512695312}, {'rank': 56, 'pmid': '25103657', 'score': 118.98600769042969}, {'rank': 57, 'pmid': '22287168', 'score': 118.93791961669922}, {'rank': 58, 'pmid': '21950 ...
